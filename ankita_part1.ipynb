# %% [markdown]
# IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# READING THE DATA

# %%
Report = pd.read_csv("Assignment Data1 - Assignment Data1.csv")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1152\965752032.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   Report = pd.read_csv("Assignment Data1 - Assignment Data1.csv")

# %%
Report
# Out:
#                Call Time    Process Name  Campaign Name            Lead Name  \
# 0       25-11-2021 11:07  Topdoc process  LTFS FOLLOWUP  LTFS HINDI FOLLOWUP
# 1       25-11-2021 11:07  Topdoc process  LTFS FOLLOWUP  LTFS HINDI FOLLOWUP
# 2       25-11-2021 11:07  Topdoc process  LTFS FOLLOWUP  LTFS HINDI FOLLOWUP
# 3       25-11-2021 11:08  Topdoc process  LTFS FOLLOWUP  LTFS HINDI FOLLOWUP
# 4       25-11-2021 11:08  Topdoc process  LTFS FOLLOWUP  LTFS HINDI FOLLOWUP
# ...                  ...             ...            ...                  ...
# 132124  06-12-2021 12:51            LTFS    LTFS Telegu                  NaN
# 132125  06-12-2021 12:52            LTFS    LTFS Telegu       LTFSTELEGU0212
# 132126  06-12-2021 12:52            LTFS    LTFS Telegu       LTFSTELEGU0212
# 132127  06-12-2021 12:53            LTFS    LTFS Telegu       LTFSTELEGU0212
# 132128  06-12-2021 12:53            LTFS    LTFS Telegu       LTFSTELEGU0212
#
# ...

# %%
Report = pd.read_csv("Assignment Data1 - Assignment Data1.csv")
Report = Report.dropna(subset = ["User Name"])
Report
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1152\480898816.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   Report = pd.read_csv("Assignment Data1 - Assignment Data1.csv")
#                Call Time    Process Name  Campaign Name            Lead Name  \
# 0       25-11-2021 11:07  Topdoc process  LTFS FOLLOWUP  LTFS HINDI FOLLOWUP
# 2       25-11-2021 11:07  Topdoc process  LTFS FOLLOWUP  LTFS HINDI FOLLOWUP
# 3       25-11-2021 11:08  Topdoc process  LTFS FOLLOWUP  LTFS HINDI FOLLOWUP
# 5       25-11-2021 11:08  Topdoc process  LTFS FOLLOWUP  LTFS HINDI FOLLOWUP
# 41      25-11-2021 11:13  Topdoc process  LTFS FOLLOWUP  LTFS HINDI FOLLOWUP
# ...                  ...             ...            ...                  ...
# 132115  06-12-2021 12:50            LTFS    LTFS Telegu       LTFSTELEGU0212
# 132117  06-12-2021 12:50            LTFS    LTFS Telegu       LTFSTELEGU0212
# ...

# %%
Report = pd.read_csv("Assignment Data1 - Assignment Data1.csv", low_memory = False)
Report = Report.groupby('User Name')
Report

# %%
Report = pd.read_csv("Assignment Data1 - Assignment Data1.csv", low_memory = False)
Report['Call Time']  =pd.to_datetime(Report['Call Time']).dt.date
Y = pd.pivot_table(Report, values = 'Call Time', index = "User Name", aggfunc = pd.Series.nunique, sort = False)
WorkingDays = Y.rename(columns = {'Call Time': 'Working Days'} )
WorkingDays
# Out:
#                                  Working Days
# User Name
# Teena patidar                              23
# Ana khan                                   22
# demouser                                    2
# Aafrin taj                                 22
# Mohd Inayat Mohd Hussain Sayyed            18
# Shabista Khan                              22
# Sneha chetan                               21
# Rupa Nerurkar                              17
# Shruti sanjeev gupta                       21
# Bindu M N                                  19
# Betsy Vinisha                               5
# Pasupuleti swathi                          21

# %%
Report = pd.read_csv("Assignment Data1 - Assignment Data1.csv", low_memory = False)
TotalAttempts = Report['User Name'].value_counts(sort = False)
TotalAttempts
# Out:
# Teena patidar                      2779
# Ana khan                           2732
# demouser                             19
# Aafrin taj                         2463
# Mohd Inayat Mohd Hussain Sayyed    2053
# Shabista Khan                      4118
# Sneha chetan                       3386
# Rupa Nerurkar                      2175
# Shruti sanjeev gupta               2664
# Bindu M N                          2435
# Betsy Vinisha                       322
# Pasupuleti swathi                  2245
# Name: User Name, dtype: int64

# %%
Report = pd.read_csv("Assignment Data1 - Assignment Data1.csv", low_memory = False)

Report = Report[Report['System Disposition']== "CONNECTED"]
Y = pd.pivot_table(Report, values = 'System Disposition', index = "User Name", aggfunc = 'count')
TotalConnects = Y.rename(columns = {'System Disposition': 'Total Connects'} )
TotalConnects
# Out:
#                                  Total Connects
# User Name
# Aafrin taj                                 1589
# Ana khan                                   1678
# Betsy Vinisha                               279
# Bindu M N                                  1948
# Mohd Inayat Mohd Hussain Sayyed            1512
# Pasupuleti swathi                          1922
# Rupa Nerurkar                              1695
# Shabista Khan                              2556
# Shruti sanjeev gupta                       1932
# Sneha chetan                               2621
# Teena patidar                              1590
# demouser                                      6

# %%
Report = pd.read_csv("Assignment Data1 - Assignment Data1.csv", low_memory = False)

Report = Report[Report['Disposition Class']== "INTERESTED"]
Y = pd.pivot_table(Report, values = 'Disposition Class', index = "User Name", aggfunc = 'count')
TotalInterested = Y.rename(columns = {'Disposition Class': 'Total Interested'} )
TotalInterested
# Out:
#                                  Total Interested
# User Name
# Aafrin taj                                    107
# Ana khan                                      248
# Betsy Vinisha                                  18
# Bindu M N                                     242
# Mohd Inayat Mohd Hussain Sayyed               104
# Pasupuleti swathi                             207
# Rupa Nerurkar                                 128
# Shabista Khan                                 230
# Shruti sanjeev gupta                          275
# Sneha chetan                                  213
# Teena patidar                                 196

# %%
Report = pd.read_csv("Assignment Data1 - Assignment Data1.csv", low_memory = False)
X = Report[(Report['Disposition Code']== "Policy Issued") + (Report['Disposition Code']== "Policy_Issued")]
Y = pd.pivot_table(X, values = 'Disposition Code', index = "User Name", aggfunc = 'count')
TotalPolicyIssued = Y.rename(columns = {'Disposition Code': 'Total Policies Issued'} )
TotalPolicyIssued
# Out:
#                                  Total Policies Issued
# User Name
# Aafrin taj                                           8
# Ana khan                                            37
# Bindu M N                                            5
# Mohd Inayat Mohd Hussain Sayyed                      5
# Pasupuleti swathi                                    7
# Rupa Nerurkar                                        3
# Shabista Khan                                        5
# Shruti sanjeev gupta                                15
# Sneha chetan                                        27
# Teena patidar                                       27

# %%
Report = pd.read_csv("Assignment Data1 - Assignment Data1.csv", low_memory = False)
Report['Call Time']  =pd.to_datetime(Report['Call Time']).dt.date

WorkingDays = pd.pivot_table(Report, values = 'Call Time', index = "User Name", aggfunc = pd.Series.nunique, sort = False)
TotalAttempts= Report['User Name'].value_counts(sort = False)
New = pd.concat([WorkingDays, TotalAttempts], axis  = 1)
New
# Out:
#                                  Call Time  User Name
# Teena patidar                           23       2779
# Ana khan                                22       2732
# demouser                                 2         19
# Aafrin taj                              22       2463
# Mohd Inayat Mohd Hussain Sayyed         18       2053
# Shabista Khan                           22       4118
# Sneha chetan                            21       3386
# Rupa Nerurkar                           17       2175
# Shruti sanjeev gupta                    21       2664
# Bindu M N                               19       2435
# Betsy Vinisha                            5        322
# Pasupuleti swathi                       21       2245

# %%
Report  = New.rename(columns = {'Call Time':'Working Days', 'User Name': 'Total Attempts'})
Report
# Out:
#                                  Working Days  Total Attempts  \
# Teena patidar                              23            2779
# Ana khan                                   22            2732
# demouser                                    2              19
# Aafrin taj                                 22            2463
# Mohd Inayat Mohd Hussain Sayyed            18            2053
# Shabista Khan                              22            4118
# Sneha chetan                               21            3386
# Rupa Nerurkar                              17            2175
# Shruti sanjeev gupta                       21            2664
# Bindu M N                                  19            2435
# Betsy Vinisha                               5             322
# Pasupuleti swathi                          21            2245
#
#                                  Total Interested  Total Policies Issued
# Teena patidar                               196.0                   27.0
# ...

# %%
Report= pd.concat([WorkingDays, TotalAttempts,TotalConnects,TotalInterested, TotalPolicyIssued], axis  = 1)
Report  =  Report.rename(columns = {'User Name': 'Total Attempts'})

# %%
Report['Average Attempts']  =  Report['Total Attempts']/Report['Working Days']
Report['Average Connects']  =  Report['Total Connects']/Report['Working Days']
Report['Average Interested']  =  Report['Total Interested']/Report['Working Days']
Report['Average Policy Issued']  =  Report['Total Policies Issued']/Report['Working Days']
Report['Connect to Attempt Ratio %']  = Report['Total Connects']/Report['Total Attempts']
Report['Connect to Interested Ratio %']  =  Report['Total Connects']/Report['Total Interested']
Report['Policies Issued to Connect Ratio %']  = Report['Total Policies Issued']/Report['Total Connects']

# %%
Report['Average Connect to Attempt Ratio %']  =  Report['Average Connects']/Report['Total Attempts']
Report['Average Connect to Interested Ratio %']  =  Report['Average Connects']/Report['Total Interested']
Report['Average Policies Issued  to Connect Ratio %']  =  Report['Average Policy Issued']/Report['Total Connects']
Report
# Out:
#                                  Working Days  Total Attempts  Total Connects  \
# Teena patidar                              23            2779            1590
# Ana khan                                   22            2732            1678
# demouser                                    2              19               6
# Aafrin taj                                 22            2463            1589
# Mohd Inayat Mohd Hussain Sayyed            18            2053            1512
# Shabista Khan                              22            4118            2556
# Sneha chetan                               21            3386            2621
# Rupa Nerurkar                              17            2175            1695
# Shruti sanjeev gupta                       21            2664            1932
# Bindu M N                                  19            2435            1948
# Betsy Vinisha                               5             322             279
# ...

# %%
pip install nb2xls
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting nb2xls
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ------------------------------------ 150.0/150.0 kB 638.1 kB/s eta 0:00:00
# ...
#      -------------------------------------- 48.1/48.1 kB 823.2 kB/s eta 0:00:00
# ...
# Using legacy 'setup.py install' for nb2xls, since package 'wheel' is not installed.
# ...
#   Running setup.py install for nb2xls: started
#   Running setup.py install for nb2xls: finished with status 'done'
# ...
# WARNING: There was an error checking the latest version of pip.
